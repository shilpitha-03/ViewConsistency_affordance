# %%
# !python --version
# !pip install ninja
# !sudo apt-get install python3.10

# !sudo apt update
# !sudo apt install python3.10-distutils python3.10-venv -y
# !curl -sS https://bootstrap.pypa.io/get-pip.py | python3.10

# !python3.10 -m pip install --upgrade pip setuptools wheel

# !python3.10 -m pip uninstall torch torchvision torchaudio
# !python3.10 -m pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Python 3.12.13
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 4.8 MB/s eta 0:00:00
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.10 is already the newest version (3.10.12-1~22.04.15).
# python3.10 set to manually installed.
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,599 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# ...

# %%
# Clone git repo and try to run make.sh, update variables
# !git clone https://github.com/Reagan1311/Aff-Grasp.git

import os
# %cd Aff-Grasp/affordance-learning/models/dino/ops/
print(os.getcwd())
# Out:
# Cloning into 'Aff-Grasp'...
# remote: Enumerating objects: 378, done.
# remote: Counting objects: 100% (378/378), done.
# remote: Compressing objects: 100% (313/313), done.
# remote: Total 378 (delta 52), reused 365 (delta 48), pack-reused 0 (from 0)
# Receiving objects: 100% (378/378), 7.11 MiB | 9.27 MiB/s, done.
# Resolving deltas: 100% (52/52), done.
# /content/Aff-Grasp/affordance-learning/models/dino/ops
# /content/Aff-Grasp/affordance-learning/models/dino/ops

# %%
# !python3.10 -c "import torch; print(torch.__version__)"
# !python3.10 setup.py build install
# Out:
# 2.5.1+cu121
# running build
# running build_py
# creating build/lib.linux-x86_64-cpython-310/modules
# copying modules/ms_deform_attn.py -> build/lib.linux-x86_64-cpython-310/modules
# copying modules/__init__.py -> build/lib.linux-x86_64-cpython-310/modules
# creating build/lib.linux-x86_64-cpython-310/functions
# copying functions/ms_deform_attn_func.py -> build/lib.linux-x86_64-cpython-310/functions
# copying functions/__init__.py -> build/lib.linux-x86_64-cpython-310/functions
# running build_ext
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:416: UserWarning: The detected CUDA version (12.8) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# ...

# %%
# %cd ../../../../..
# %cd Aff-Grasp/affordance-learning/
print(os.getcwd())
# !wget https://huggingface.co/Gen1113/Model_for_Aff-Grasp/resolve/main/best_8_iou_68.4.pth
# !ls
# Out:
# /content
# /content/Aff-Grasp/affordance-learning
# /content/Aff-Grasp/affordance-learning
# --2026-04-30 01:21:21--  https://huggingface.co/Gen1113/Model_for_Aff-Grasp/resolve/main/best_8_iou_68.4.pth
# Resolving huggingface.co (huggingface.co)... 18.164.174.118, 18.164.174.23, 18.164.174.17, ...
# Connecting to huggingface.co (huggingface.co)|18.164.174.118|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !python3.10 -m pip install -U huggingface_hub
# !hf auth login
# !hf auth login
# !hf download Gen1113/Data_for_Aff-Grasp \
  --repo-type dataset \
  --local-dir ./ag_dataset

# This terminal will need to run for 10min or so
# once it seems like it isn't pulling more data it should be manually terminated
# and continue on with the notebook
# Out:
#   A new version of huggingface_hub is available: 1.11.0 → 1.12.2
#
#   Do you want to update now? [Y/n] (/usr/bin/python3 -m pip install -U huggingface_hub) y
#
#   Running: /usr/bin/python3 -m pip install -U huggingface_hub
#
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.8/647.8 kB 18.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface_hub 1.11.0
#     Uninstalling huggingface_hub-1.11.0:
#       Successfully uninstalled huggingface_hub-1.11.0
# ...
#
#   ✓ Successfully updated huggingface_hub to 1.12.2. Please re-run your command.
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
# ...

# %%
# %cd ag_dataset/
# !mv Data_for_Aff-Grasp/* .
# !rmdir Data_for_Aff-Grasp
# !ls
# %cd ..
# Out:
# /content/Aff-Grasp/affordance-learning/ag_dataset
# Affordance_Evaluation_Dataset
# /content/Aff-Grasp/affordance-learning

# %%
# needs work

# !python3.10 -m pip install opencv-python tqdm timm peft matplotlib

# !MPLBACKEND=Agg python3.10 test.py --model_file best_8_iou_68.4.pth
# Out:
# ...
#   Using cached huggingface_hub-1.12.2-py3-none-any.whl.metadata (14 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 47.2 MB/s  0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 116.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 680.7/680.7 kB 39.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 147.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 153.6 MB/s  0:00:00
# Using cached huggingface_hub-1.12.2-py3-none-any.whl (647 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 158.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 94.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.3/770.3 kB 44.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 123.4 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 129.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 793.6/793.6 kB 41.0 MB/s  0:00:00
# ...
